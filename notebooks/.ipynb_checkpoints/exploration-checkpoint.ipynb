# %% [markdown]
# # Data Exploration

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading in the data

# %%
data = pd.read_csv('/Users/christianmonsalve/Desktop/CODE/Projects/Movie_Recs/data/processed/movies_cleaned.csv')

# %% [markdown]
# ### Basic Data Inspection

# %%
data.head()
# Out:
#       tconst titleType                   primaryTitle  \
# 0  tt0000009     movie                     Miss Jerry
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 2  tt0000335     movie          Soldiers of the Cross
# 3  tt0000502     movie                       Bohemios
# 4  tt0000574     movie    The Story of the Kelly Gang
#
#                    originalTitle  startYear  endYear  runtimeMinutes  \
# 0                     Miss Jerry       1894     2014              45
# 1  The Corbett-Fitzsimmons Fight       1897     2014             100
# 2          Soldiers of the Cross       1900     2014              40
# 3                       Bohemios       1905     2014             100
# 4    The Story of the Kelly Gang       1906     2014              70
#
#                        genres  averageRating  numVotes
# 0                     Romance            5.2     232.0
# 1      Documentary,News,Sport            5.3     584.0
# 2             Biography,Drama            5.4      67.0
# ...

# %%
data.tail()
# Out:
#            tconst titleType  \
# 737030  tt9916622     movie
# 737031  tt9916680     movie
# 737032  tt9916706     movie
# 737033  tt9916730     movie
# 737034  tt9916754     movie
#
#                                              primaryTitle  \
# 737030        Rodolpho Teóphilo - O Legado de um Pioneiro
# 737031  De la ilusión al desconcierto: cine colombiano...
# 737032                                    Dankyavar Danka
# 737033                                             6 Gunn
# 737034                     Chico Albuquerque - Revelações
#
#                                             originalTitle  startYear  endYear  \
# 737030        Rodolpho Teóphilo - O Legado de um Pioneiro       2015     2014
# 737031  De la ilusión al desconcierto: cine colombiano...       2007     2014
# 737032                                    Dankyavar Danka       2013     2014
# 737033                                             6 Gunn       2017     2014
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737035 entries, 0 to 737034
# Data columns (total 10 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          737035 non-null  object
#  1   titleType       737035 non-null  object
#  2   primaryTitle    737035 non-null  object
#  3   originalTitle   737035 non-null  object
#  4   startYear       737035 non-null  int64
#  5   endYear         737035 non-null  int64
#  6   runtimeMinutes  737035 non-null  int64
#  7   genres          737035 non-null  object
#  8   averageRating   338186 non-null  float64
#  9   numVotes        338186 non-null  float64
# dtypes: float64(2), int64(3), object(5)
# memory usage: 56.2+ MB

# %%
description = data.describe()

def format_description(df):
    df = df.copy()
    cols = list(df.columns)
    for col in cols:
        df[col] = round(df[col], ndigits=2)

    return df
        
formatted_description = format_description(description)

# %%
formatted_description
# Out:
#        startYear   endYear  runtimeMinutes  averageRating    numVotes
# count  737035.00  737035.0       737035.00      338186.00   338186.00
# mean     1997.42    2014.0           67.73           6.17     3694.45
# std        28.59       0.0          119.91           1.38    37576.31
# min      1894.00    2014.0            1.00           1.00        5.00
# 25%      1984.00    2014.0           30.00           5.30       20.00
# 50%      2012.00    2014.0           69.00           6.30       64.00
# 75%      2016.00    2014.0           92.00           7.10      325.00
# max      2031.00    2014.0        59460.00          10.00  3145376.00

# %% [markdown]
# ### Double check duplicates and missing values

# %%
print("Duplicates: ", data.duplicated().sum())
print("Missing values: ", data.isnull().any(axis=1).sum())
# Out:
# Duplicates:  0
# Missing values:  398849

# %%
data.loc[data.isnull().any(axis=1), :].sample()
# Out:
#            tconst titleType primaryTitle originalTitle  startYear  endYear  \
# 191657  tt0393315     movie        Ganba         Ganba       1961     2014
#
#         runtimeMinutes  genres  averageRating  numVotes
# 191657              30  Comedy            NaN       NaN

# %%
data['numVotes'] = data['numVotes'].fillna(0)
data['averageRating'] = data['averageRating'].fillna(round(data['averageRating'].mean(), 1))

# %%
data.iloc[550969]
# Out:
# tconst                               tt3552190
# titleType                                movie
# primaryTitle      Ferramonti: Il campo sospeso
# originalTitle     Ferramonti: Il campo sospeso
# startYear                                 2013
# endYear                                   2014
# runtimeMinutes                              30
# genres                             Documentary
# averageRating                              6.2
# numVotes                                   0.0
# Name: 550969, dtype: object

# %%
print("Missing values: ", data.isnull().any(axis=1).sum())
# Out:
# Missing values:  0

# %% [markdown]
# ## Deeper Analysis

# %%
# All genres listed in our data
possible_genres = list(data['genres'].unique())
genres = set()

for genre in possible_genres:
    for g in genre.split(','):
        genres.add(g)

genres = list(genres)

# %%
print("Number of genres in our data: ", len(genres))
print("Genres:\n", genres)
# Out:
# Number of genres in our data:  29
# Genres:
#  ['Horror', 'Romance', 'Family', 'Documentary', 'Drama', 'Game-Show', 'Mystery', 'Adult', 'Western', 'War', 'Crime', 'Adventure', 'Biography', 'Film-Noir', 'Reality-TV', 'Unknown', 'History', 'Animation', 'News', 'Sci-Fi', 'Thriller', 'Fantasy', 'Music', 'Talk-Show', 'Sport', 'Comedy', 'Short', 'Musical', 'Action']

# %%
plt.figure(figsize=(10, 6))
plt.title("Histogram of Movie Start Years", fontsize=20, pad=15)
plt.xlabel("Start Year", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.histplot(data=data, x='startYear', bins=20)

plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10, 6))
plt.title("Histogram of Movie End Years", fontsize=20, pad=15)
plt.xlabel("End Year", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.histplot(data=data, x='endYear', bins=20)

plt.plot()
# Out:
# []

# %% [markdown]
# <p><b>Note:</b> Looks like endYears is a good column to drop.</p>

# %%
data = data.drop(columns='endYear')
data = data.rename(columns={'startYear': 'year'})

# %%
data.head()
# Out:
#       tconst titleType                   primaryTitle  \
# 0  tt0000009     movie                     Miss Jerry
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight
# 2  tt0000335     movie          Soldiers of the Cross
# 3  tt0000502     movie                       Bohemios
# 4  tt0000574     movie    The Story of the Kelly Gang
#
#                    originalTitle  year  runtimeMinutes  \
# 0                     Miss Jerry  1894              45
# 1  The Corbett-Fitzsimmons Fight  1897             100
# 2          Soldiers of the Cross  1900              40
# 3                       Bohemios  1905             100
# 4    The Story of the Kelly Gang  1906              70
#
#                        genres  averageRating  numVotes
# 0                     Romance            5.2     232.0
# 1      Documentary,News,Sport            5.3     584.0
# 2             Biography,Drama            5.4      67.0
# 3                     Unknown            3.1      26.0
# ...

# %%
def find_outliers_iqr(data):
    # Calculate Q1 (25th percentile) and Q3 (75th percentile)
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    
    # Calculate the Interquartile Range (IQR)
    IQR = Q3 - Q1
    
    # Define the lower and upper bounds for outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Identify outliers
    outliers = [i for i, x in enumerate(data) if x < lower_bound or x > upper_bound]
    
    print(f"Lower bound (Lower fence): {lower_bound}")
    print(f"Upper bound (Upper fence): {upper_bound}")
    
    return outliers

# %%
runTimeOutliersIndexes = find_outliers_iqr(data['runtimeMinutes'])
data.iloc[runTimeOutliersIndexes].sample(5)
# Out:
# Lower bound (Lower fence): -63.0
# Upper bound (Upper fence): 185.0
#             tconst titleType  primaryTitle originalTitle  year  \
# 77473    tt0111341     movie    Satantango    Sátántangó  1994
# 392767  tt20123090     movie           You           You  2013
# 127613   tt0216330     movie  Uyira Manama  Uyira Manama  1968
# 640195   tt5375100     movie  Paint Drying  Paint Drying  2016
# 210012   tt0479651     movie  Dasavatharam  Dasavatharam  2008
#
#         runtimeMinutes                  genres  averageRating  numVotes
# 77473              439                   Drama            8.2   13858.0
# 392767             326                   Drama            6.2       0.0
# 127613             188                 Unknown            6.2       0.0
# 640195             607             Documentary            9.1    1560.0
# 210012             188  Action,Adventure,Drama            7.3   11466.0

# %%
plt.figure(figsize=(10, 6))
plt.title("Boxplot to Identify Outliers in Movie Runtimes", fontsize=20, pad=15)
plt.xlabel("Movie Runtimes", fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

sns.boxplot(data=data, x="runtimeMinutes")
plt.plot()
# Out:
# []

# %%
# Dropped movies with really long runtime
data = data.query("runtimeMinutes < 300")

# %%
plt.figure(figsize=(10, 6))
plt.title("Much Better Boxplot of Movie Runtimes", fontsize=20, pad=15)
plt.xlabel("Movie Runtimes", fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)

sns.boxplot(data=data, x="runtimeMinutes")
plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10, 6))
plt.title("Histogram of Movie Run Times", fontsize=20, pad=15)
plt.xlabel("Run Times (min)", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.histplot(data=data, x='runtimeMinutes', bins=20)

plt.plot()
# Out:
# []

# %%
plt.figure(figsize=(10, 6))
plt.title("Histogram of Average Ratings", fontsize=20, pad=15)
plt.xlabel("Average Ratings", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
sns.histplot(data=data, x='averageRating', bins=10)

plt.plot()
# Out:
# []

# %%
genres_dict = dict.fromkeys(genres, 0)

# %%
for genres_str in data['genres']:
    for genre in genres_str.split(','):
        genres_dict[genre] += 1

# %%
genres_dict
# Out:
# {'Horror': 45760,
#  'Romance': 53010,
#  'Family': 19750,
#  'Documentary': 145135,
#  'Drama': 269091,
#  'Game-Show': 33,
#  'Mystery': 20140,
#  'Adult': 9223,
#  'Western': 8039,
#  'War': 10062,
#  'Crime': 42592,
#  'Adventure': 31414,
#  'Biography': 19654,
#  'Film-Noir': 877,
#  'Reality-TV': 599,
#  'Unknown': 77794,
#  'History': 16392,
#  'Animation': 11001,
#  'News': 1496,
#  'Sci-Fi': 16158,
#  'Thriller': 52257,
#  'Fantasy': 17879,
#  'Music': 15099,
#  'Talk-Show': 215,
#  'Sport': 8738,
#  'Comedy': 122737,
#  'Short': 3,
#  'Musical': 11149,
#  'Action': 60752}

# %%
plt.figure(figsize=(10, 6))
plt.title("Genre Distribution", fontsize=20, pad=15)
plt.xlabel("Average Ratings", fontsize=14)
plt.ylabel("Count", fontsize=14)
plt.xticks(fontsize=10, rotation=90)
plt.yticks(fontsize=10)
sns.barplot(x=genres_dict.keys(), y=genres_dict.values())

plt.plot()
# Out:
# []

# %%
print("Latest movie year: ", data['year'].max())
print("Earliest movie year: ", data['year'].min())
# Out:
# Latest movie year:  2031
# Earliest movie year:  1894

# %%
data[data['year'] > 2026].sample(5)
# Out:
#             tconst titleType           primaryTitle          originalTitle  \
# 545645  tt35050152     movie       Bluey: The Movie       Bluey: The Movie
# 407260  tt21361444     movie  Avengers: Secret Wars  Avengers: Secret Wars
# 588904  tt38681919     movie              Zac Power              Zac Power
# 680527   tt7008874     movie           Margie Claus           Margie Claus
# 447856  tt26443622     movie        Untitled Disney        Untitled Disney
#
#         year  runtimeMinutes                      genres  averageRating  \
# 545645  2027              30  Adventure,Animation,Comedy            6.2
# 407260  2027              30     Action,Adventure,Sci-Fi            6.2
# 588904  2027              30                       Drama            6.2
# 680527  2027              30    Animation,Comedy,Musical            6.2
# 447856  2027              30                     Unknown            6.2
#
#         numVotes
# 545645       0.0
# 407260       0.0
# 588904       0.0
# ...

# %%
data.query('primaryTitle != originalTitle and year > 2000').sample(5)
# Out:
#             tconst titleType primaryTitle  \
# 730021   tt9502538     movie  Caged Birds
# 232211  tt10287954     movie  Rose Island
# 165728   tt0313419     movie     Jazz War
# 221403   tt0900381     movie     Trackman
# 238200   tt1051825     movie     Dementia
#
#                                      originalTitle  year  runtimeMinutes  \
# 730021           Stürm: Bis wir tot sind oder frei  2020             118
# 232211  L'incredibile storia dell'isola delle rose  2020             117
# 165728                                        Ocet  2001              30
# 221403                          Putevoy obkhodchik  2007              80
# 238200                                       Junun  2006             104
#
#                             genres  averageRating  numVotes
# 730021         Crime,Drama,History            5.9     309.0
# 232211  Adventure,Biography,Comedy            7.0   27321.0
# 165728           Documentary,Music            5.2      11.0
# ...

# %%
data = data.drop(columns='originalTitle')

# %%
data.head()
# Out:
#       tconst titleType                   primaryTitle  year  runtimeMinutes  \
# 0  tt0000009     movie                     Miss Jerry  1894              45
# 1  tt0000147     movie  The Corbett-Fitzsimmons Fight  1897             100
# 2  tt0000335     movie          Soldiers of the Cross  1900              40
# 3  tt0000502     movie                       Bohemios  1905             100
# 4  tt0000574     movie    The Story of the Kelly Gang  1906              70
#
#                        genres  averageRating  numVotes
# 0                     Romance            5.2     232.0
# 1      Documentary,News,Sport            5.3     584.0
# 2             Biography,Drama            5.4      67.0
# 3                     Unknown            3.1      26.0
# 4  Action,Adventure,Biography            6.0    1047.0

# %%
data.to_csv('/Users/christianmonsalve/Desktop/CODE/Projects/Movie_Recs/data/processed/explored_movies.csv', index=False)
